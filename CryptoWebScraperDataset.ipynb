# %%
# import libraries 
from bs4 import BeautifulSoup
import requests
import csv
import datetime


# Connect to the crypto.com website and retrieve data
URL = 'https://crypto.com/price'

# Set headers to mimic a web browser's request
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

# Make a request to the URL with the specified headers
page = requests.get(URL, headers=headers)

# Create a BeautifulSoup object to parse the HTML content
soup1 = BeautifulSoup(page.content, "html.parser")
soup2 = BeautifulSoup(soup1.prettify(), "html.parser")

# Extract relevant data from the HTML
title = soup2.find(class_='chakra-text css-1fa2juv').get_text()
header = soup2.find_all(class_='css-1rh2lcy')
coin = soup2.find_all(class_='chakra-text css-rkws3')
price = soup2.find_all(class_='chakra-text css-5a8n3t')
market_cap = soup2.find_all(class_='css-15lyn3l')
day_volume = soup2.find_all(class_='css-15lyn3l')

# Create a timestamp for tracking when the data was collected
timestamp = datetime.datetime.now().strftime("%Y/%m/%d %H:%M:%S")

# Clean up the data and print coin details
print (title)

# Iterate over coins and prices, printing and saving data to CSV
for i in range(0, min(len(name), len(titles)), 4):
    coinname_title = name[i+0].get_text().strip()
    coinprice_title = header[i+1].get_text().strip()
    market_cap_title = header[i+4].get_text().strip()
    day_volum_title = header[i+3].get_text().strip()
    print(f"{coinname_title} - {coinprice_title} - {market_cap_title} - {day_volum_title} - Data collected at ")


# Create CSV and write headers and data into the file
header = ['Name', 'Price', 'Market_cap', '24H_volume', 'Data collected at']

with open('CryptoWebScraperDataset.csv', 'a', newline='', encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(header)

    # Iterate the data simultaneously
    for (coin, price), i in zip(zip(coin, price), range(0, min(len(market_cap), len(day_volume)), 2)):
        coin_value = coin.get_text().strip()
        price_value = price.get_text().strip()
        cap_value = market_cap[i + 1].get_text().strip()
        volume_value = day_volume[i].get_text().strip()
        
        # Print the values
        print(f"{coin_value} - {price_value} - {cap_value} - {volume_value} - {timestamp}")

        # Write data to CSV file
        writer.writerow([coin_value, price_value, cap_value, volume_value, timestamp])
# Print the values
    print(f"{coin_value} - {price_value} - {cap_value} - {volume_value} - {timestamp}")
# Out:
#          Today's Cryptocurrency Prices
#
#  - Price - Market Cap - 24H VOLUME - Data collected at
# Bitcoin - $41,927.51 - $820.63 B - $14.43 B - 2023/12/17 15:12:33
# Ethereum - $2,217.37 - $266.53 B - $6.59 B - 2023/12/17 15:12:33
# Tether - $1.00 - $90.97 B - $34.23 B - 2023/12/17 15:12:33
# BNB - $241.73 - $36.67 B - $652.98 M - 2023/12/17 15:12:33
# XRP - $0.6183 - $33.39 B - $823.92 M - 2023/12/17 15:12:33
# Solana - $72.22 - $30.89 B - $1.49 B - 2023/12/17 15:12:33
# USD Coin - $1.00 - $24.66 B - $3.63 B - 2023/12/17 15:12:33
# Cardano - $0.5977 - $21.12 B - $542.75 M - 2023/12/17 15:12:33
# Avalanche - $41.75 - $15.28 B - $1.68 B - 2023/12/17 15:12:33
# Dogecoin - $0.0945 - $13.44 B - $538.62 M - 2023/12/17 15:12:33
# TRON - $0.103 - $9.11 B - $185.26 M - 2023/12/17 15:12:33
# Polkadot - $6.96 - $8.75 B - $275.45 M - 2023/12/17 15:12:33
# Chainlink - $14.17 - $8.05 B - $362.82 M - 2023/12/17 15:12:33
# Polygon - $0.8325 - $7.95 B - $309.12 M - 2023/12/17 15:12:33
# ...
